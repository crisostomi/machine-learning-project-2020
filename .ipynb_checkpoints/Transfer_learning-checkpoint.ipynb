# %%
import numpy as np
import pandas as pd
import cv2
import os
from sklearn.model_selection import train_test_split
import skimage.transform
import sklearn
import matplotlib.pyplot as plt
from keras.applications import xception
from sklearn.utils import shuffle
import tensorflow.compat.v1 as tf
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from keras import backend as K
from keras.applications.xception import decode_predictions
import keract
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Paths

# %%
ten_breeds_path = './dataset/10-breeds/'

# %%
img_size = 299

def load_pictures(dataset_path):
    X, y = [], [];
    for breed in os.listdir(dataset_path):
        if breed.startswith('.'):
            continue
        breed_folder = dataset_path+breed
        for img_file in os.listdir(breed_folder):
            img_path = breed_folder + '/'+ img_file
            img = cv2.imread(img_path)
            resized_img = cv2.resize(img, (img_size,img_size))
            X.append(resized_img)
            y.append(breed)
    return np.asarray(X),np.asarray(y)

# %% [markdown]
# ### Load dataset

# %%
X_dataset, y_dataset = load_pictures(ten_breeds_path)
X_dataset, y_dataset = shuffle(X_dataset, y_dataset)

# %% [markdown]
# ###  Adequate data to the format the model requires

# %%
X_dataset_xcept = xception.preprocess_input(X_dataset)
print('Train Images shape: {} size: {:,}'.format(X_dataset_xcept.shape, X_dataset_xcept.size))
# Out:
# Train Images shape: (1636, 299, 299, 3) size: 438,780,108

# %% [markdown]
# ### Split dataset in train and test sets

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X_dataset_xcept, y_dataset, test_size=0.20, random_state=0)

# %% [markdown]
# ### One-hot encoding on the labels

# %%
le = LabelEncoder()

le.fit(y_train)
y_train = le.transform(y_train) 
le.fit(y_test)
y_test = le.transform(y_test)

print("Check if shapes are correct: \n \t X_train shape: {}, y_train shape: {} \n\t X_test shape: {}, y_test shape: {}".format(X_train.shape, y_train.shape, X_test.shape, y_test.shape))

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
numb_labels = y_train.shape[1]
# Out:
# Check if shapes are correct:
#  	 X_train shape: (1308, 299, 299, 3), y_train shape: (1308,)
# 	 X_test shape: (328, 299, 299, 3), y_test shape: (328,)

# %% [markdown]
# ### Fit model with Xception model

# %%
xception_bottleneck = xception.Xception(weights='imagenet', include_top=False, pooling='avg')
train_X_bf = xception_bottleneck.predict(X_train, batch_size=32, verbose=1)
valid_X_bf = xception_bottleneck.predict(X_test, batch_size=32, verbose=1)
print('Xception train bottleneck features shape: {} size: {:,}'.format(train_X_bf.shape, train_X_bf.size))
print('Xception valid bottleneck features shape: {} size: {:,}'.format(valid_X_bf.shape, valid_X_bf.size))
# Out:
# ...
# 328/328 [==============================] - 53s 162ms/step
# Xception train bottleneck features shape: (1308, 2048) size: 2,678,784
# Xception valid bottleneck features shape: (328, 2048) size: 671,744

# %% [markdown]
# ### Apply Logisitc regression on the output of the model and evaluate it

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, accuracy_score

logreg = LogisticRegression(multi_class='multinomial', solver='lbfgs', random_state=0)
logreg.fit(train_X_bf, (y_train * range(numb_labels)).sum(axis=1))
valid_probs = logreg.predict_proba(valid_X_bf)
valid_preds = logreg.predict(valid_X_bf)
print('Validation Xception LogLoss {}'.format(log_loss(y_test, valid_probs)))
print('Validation Xception Accuracy {}'.format(accuracy_score((y_test * range(numb_labels)).sum(axis=1), valid_preds)))
# Out:
# Validation Xception LogLoss 0.07189600410270486
# Validation Xception Accuracy 0.975609756097561
# /home/don/.local/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn.metrics import classification_report
y_test = np.argmax(y_test, axis=1)
print(classification_report(y_test, valid_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      0.97      0.99        38
#            2       1.00      0.97      0.98        29
#            3       1.00      0.96      0.98        27
#            4       1.00      1.00      1.00        32
#            5       0.93      0.89      0.91        28
#            6       0.91      0.95      0.93        43
#            7       0.96      1.00      0.98        26
#            8       0.97      1.00      0.99        37
#            9       1.00      1.00      1.00        39
#
#     accuracy                           0.98       328
#    macro avg       0.98      0.97      0.98       328
# weighted avg       0.98      0.98      0.98       328

# %% [markdown]
# ### Visualizing convnet filters

# %%
model = xception.Xception(weights='imagenet', include_top=True, pooling='avg')
print(model.summary())
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = np.clip(x, 0, 255).astype('uint8')
    return x

def generate_pattern(layer_name, filter_index, size=150):
    # Build a loss function that maximizes the activation
    # of the nth filter of the layer considered.
    layer_output = model.get_layer(layer_name).output
    loss = K.mean(layer_output[:, :, :, filter_index])

    # Compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, model.input)[0]

    # Normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # This function returns the loss and grads given the input picture
    iterate = K.function([model.input], [loss, grads])
    
    # We start from a gray image with some noise
    input_img_data = np.random.random((1, size, size, 3)) * 20 + 128.

    # Run gradient ascent for 40 steps
    step = 1.
    for i in range(40):
        loss_value, grads_value = iterate([input_img_data])
        input_img_data += grads_value * step
        
    img = input_img_data[0]
    return deprocess_image(img)

# %%
def plot_filters_layer(layer_name, model):
    size = model.get_layer(layer_name).output_shape[3]
    margin = 5
    numb_columns = 8
    numb_rows = size//8
    
    # This a empty (black) image where we will store our results.
    results = np.zeros((numb_rows * size + (numb_rows-1) * margin, numb_columns * size + (numb_columns-1) * margin, 3))

    for i in range(numb_rows):  # iterate over the rows of our results grid
        for j in range(numb_columns):  # iterate over the columns of our results grid
            # Generate the pattern for filter `i + (j * 8)` in `layer_name`
            filter_img = generate_pattern(layer_name, i + (j * numb_rows), size)
            # Put the result in the square `(i, j)` of the results grid
            horizontal_start = i * size + i * margin
            horizontal_end = horizontal_start + size
            vertical_start = j * size + j * margin
            vertical_end = vertical_start + size
            results[horizontal_start: horizontal_end, vertical_start: vertical_end, :] = filter_img
    fig_width = 20
    fig_height = 10*(numb_rows/4)
    plt.figure(figsize=(fig_width, fig_height))
    results = results/255.0
    plt.imshow(results)
    plt.show()
    #plt.savefig(layer_name+'.png')

plot_filters_layer('block1_conv1', model)

# %% [markdown]
# ### Visualizing heatmaps of class activation

# %%
model = xception.Xception(weights='imagenet', include_top=True, pooling='avg')
img_size = 299
boxer_path = '/home/don/imgs_for_plots/boxer.jpg'
boxer_img = cv2.imread(boxer_path)
resized_img = cv2.resize(boxer_img, (img_size,img_size))
preprocessed_img = xception.preprocess_input(np.expand_dims(resized_img.copy(), axis=0 ) )
yhat = model.predict(preprocessed_img)

label = decode_predictions(yhat)
label = label[0][0]
print('{} ({})'.format(label[1], label[2] * 100))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
activations = keract.get_activations(model, preprocessed_img, layer_name='block1_conv1')
keract.display_heatmaps(activations, boxer_img)
# Out:
# boxer (99.45186972618103)
# block1_conv1_7 (1, 149, 149, 32)
